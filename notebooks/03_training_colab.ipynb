# %% [markdown]
# # 03 — Training on Google Colab
#
# Run Swahili-100 training on Google Colab (free T4 GPU).
#
# Steps:
# 1. Clone repo and install deps
# 2. Upload/download data
# 3. Run debug training to verify
# 4. Run ablations on free tier
#
# **Note:** Full training requires a rented GPU (H100). This notebook is for ablations and debugging.

# %%
# Clone and setup
# !git clone https://github.com/marcoharuni/swahili-100.git
# %cd swahili-100
# !pip install -r requirements.txt -q

# %%
# Check GPU
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'Memory: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB')

# %%
# Debug training run
# !python train.py --config configs/debug.yaml

# %%
# TODO: Run hyperparameter ablations
