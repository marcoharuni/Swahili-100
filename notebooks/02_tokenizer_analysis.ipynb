# %% [markdown]
# # 02 — Tokenizer Analysis
#
# Train and analyze the custom Swahili BPE tokenizer.
#
# Goals:
# - Train BPE on Swahili corpus
# - Measure compression ratio vs English tokenizers
# - Visualize token boundaries on Swahili text
# - Verify morphological coverage

# %%
import sys
sys.path.insert(0, '..')

from data.tokenizer import BPETokenizer

# TODO: Train tokenizer on sample data

# %%
# TODO: Compression ratio analysis

# %%
# TODO: Compare with English tokenizers

# %%
# TODO: Visualize token boundaries
