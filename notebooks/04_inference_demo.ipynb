# %% [markdown]
# # 04 — Inference Demo
#
# Load the trained Swahili-100 model and generate text.
#
# Demonstrates:
# - Loading from checkpoint
# - Text generation with different strategies
# - Quantized inference (INT4/INT8)
# - Performance benchmarking

# %%
import sys
sys.path.insert(0, '..')

import torch
from model.config import ModelConfig
from model.transformer import Transformer
from model.generate import Generator
from data.tokenizer import BPETokenizer
from utils.checkpoint import load_checkpoint

# %%
# TODO: Load model and tokenizer from checkpoint

# %%
# TODO: Generate Swahili text with different prompts

# %%
# TODO: Quantized inference demo

# %%
# TODO: Benchmark tokens/sec
