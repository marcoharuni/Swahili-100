# %% [markdown]
# # 01 — Data Exploration
#
# Explore the raw Swahili text data before processing.
#
# Goals:
# - Understand data volume and quality per source
# - Character and word frequency distributions
# - Sample inspection
# - Language detection accuracy

# %%
import os
import sys
sys.path.insert(0, '..')

# TODO: Load and explore raw data

# %%
# TODO: Character frequency distribution

# %%
# TODO: Word frequency distribution

# %%
# TODO: Sample documents
